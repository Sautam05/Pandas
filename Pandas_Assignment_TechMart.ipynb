# %% [markdown]
# <a href="https://colab.research.google.com/github/Sautam05/Pandas/blob/main/Pandas_Assignment_TechMart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Assignment - TechMart Sales Dataset
#
# Load `TechMart_Sales_300Rows.csv` and solve the following questions.

# %% [markdown]
# ## Q1. Load the CSV file.

# %%
# Write your code
import pandas as pd
import numpy as np

df = pd.read_csv("TechMart_Sales_300Rows.csv")

# %% [markdown]
# ## Q2. Display first 10 rows.

# %%
# Write your code here
df.head()
# Out:
#   Order_ID     Customer_Name      Product     Category     Brand  Price  \
# 0  ORD1001    Anjali Gupta         Laptop  Electronics        HP  32598
# 1  ORD1002       Deepak Jain      Printer       Office     Canon   4405
# 2  ORD1003     Harsh Agrawal        Mouse  Accessories  Logitech  29393
# 3  ORD1004       Pooja Yadav      Monitor  Electronics      Dell  28721
# 4  ORD1005       Arjun Mehta  Smart Watch  Electronics     Apple   6195
#
#    Quantity    City  State  Order_Date Delivery_Status  Rating  \
# 0         2    Pune     MH  27-01-2025       Cancelled     2.0
# 1         1  Bhopal     MP  01-03-2025       Cancelled     2.0
# 2         4  Jaipur     RJ  13-03-2025       Delivered     5.0
# 3         3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4         4    Pune     MH  01-02-2025         Pending     5.0
#
#                             Review Payment_Mode
# 0          Poor Quality (Returned)          UPI
# 1                Amazing (5 Stars)          UPI
# 2  Average Quality (Late Delivery)   Debit Card
# 3         Good Product (Satisfied)  Credit Card
# 4         Good Product (Satisfied)  Net Banking

# %% [markdown]
# ## Q3. Display last 5 rows.

# %%
# Write your code here
df.tail(5)
# Out:
#     Order_ID    Customer_Name      Product     Category     Brand  Price  \
# 298  ORD1299    Harsh Agrawal     Keyboard  Accessories  Logitech  43227
# 299  ORD1300    Pooja Yadav    Smart Watch  Electronics     Apple  51951
# 300  ORD1011      Simran Kaur     Keyboard  Accessories  Logitech  18801
# 301  ORD1012      Deepak Jain      Printer       Office     Canon  29246
# 302  ORD1013      Rohit Patel     Keyboard  Accessories  Logitech  78672
#
#      Quantity    City State  Order_Date Delivery_Status  Rating  \
# 298         2  Nagpur    MH  30-01-2025         Pending     4.0
# 299         5  Jaipur    RJ  31-03-2025         Pending     1.0
# 300         2    Pune    MH  18-05-2025         Pending     5.0
# 301         2  Nagpur    MH  07-05-2025       Delivered     5.0
# 302         1  Jaipur    RJ  08-04-2025       Cancelled     4.0
#
#                                 Review Payment_Mode
# 298     Nice Product (Value for Money)  Net Banking
# 299     Nice Product (Value for Money)  Net Banking
# 300                  Amazing (5 Stars)   Debit Card
# 301  Excellent Product (Fast Delivery)          UPI
# 302     Nice Product (Value for Money)  Net Banking

# %% [markdown]
# ## Q4. Check shape, columns and data types.

# %%
# Write your code here
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# (303, 14)
# Index(['Order_ID', 'Customer_Name', 'Product', 'Category', 'Brand', 'Price',
#        'Quantity', 'City', 'State', 'Order_Date', 'Delivery_Status', 'Rating',
#        'Review', 'Payment_Mode'],
#       dtype='object')
# Order_ID            object
# Customer_Name       object
# Product             object
# Category            object
# Brand               object
# Price                int64
# Quantity             int64
# City                object
# State               object
# Order_Date          object
# Delivery_Status     object
# Rating             float64
# Review              object
# Payment_Mode        object
# dtype: object

# %% [markdown]
# ## Q5. Find null values.

# %%
# Write your code here
df.isnull().sum()
# Out:
# Order_ID           0
# Customer_Name      0
# Product            0
# Category           0
# Brand              0
# Price              0
# Quantity           0
# City               0
# State              0
# Order_Date         0
# Delivery_Status    0
# Rating             5
# Review             0
# Payment_Mode       0
# dtype: int64

# %% [markdown]
# ## Q6. Fill missing Rating with 0.

# %%
# Write your code here
df['Rating'] = df['Rating'].fillna(0)

# %% [markdown]
# ## Q7. Rename `Customer_Name` to `Customer`.

# %%
# Write your code here
df.rename(columns={'Customer_Name': 'Customer'}, inplace=True)

# %% [markdown]
# ## Q8. Delete `Brand` column.

# %%
# Write your code here
#df.drop('Brand', axis=1, inplace=True)
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer', 'Product', 'Category', 'Brand', 'Price',
#        'Quantity', 'City', 'State', 'Order_Date', 'Delivery_Status', 'Rating',
#        'Review', 'Payment_Mode'],
#       dtype='object')

# %% [markdown]
# ## Q9. Create `Total_Amount = Price * Quantity`.

# %%
# Write your code here
df['Total_Amount'] = df['Price'] * df['Quantity']

# %% [markdown]
# ## Q10. Display only Customer, Product and Total_Amount.

# %%
# Write your code here
df[['Customer', 'Product', 'Total_Amount']]
# Out:
#              Customer      Product  Total_Amount
# 0      Anjali Gupta         Laptop         65196
# 1         Deepak Jain      Printer          4405
# 2       Harsh Agrawal        Mouse        117572
# 3         Pooja Yadav      Monitor         86163
# 4         Arjun Mehta  Smart Watch         24780
# ..                ...          ...           ...
# 298     Harsh Agrawal     Keyboard         86454
# 299     Pooja Yadav    Smart Watch        259755
# 300       Simran Kaur     Keyboard         37602
# 301       Deepak Jain      Printer         58492
# 302       Rohit Patel     Keyboard         78672
#
# [303 rows x 3 columns]

# %% [markdown]
# ## Q11. Show Delivered orders.

# %%
# Write your code here
df[df['Delivery_Status'] == 'Delivered']
# Out:
#     Order_ID       Customer   Product     Category     Brand  Price  Quantity  \
# 2    ORD1003  Harsh Agrawal     Mouse  Accessories  Logitech  29393         4
# 8    ORD1009    Simran Kaur   Printer       Office     Canon  73500         2
# 11   ORD1012    Deepak Jain   Printer       Office     Canon  29246         2
# 16   ORD1017  Sakshi Sharma    Tablet  Electronics     Apple   3052         1
# 17   ORD1018    Deepak Jain    Mobile  Electronics   Samsung  64199         1
# ..       ...            ...       ...          ...       ...    ...       ...
# 292  ORD1293    Rohit Patel    Tablet  Electronics     Apple  63777         1
# 294  ORD1295    Simran Kaur   Speaker  Accessories      Boat   9304         3
# 296  ORD1297      Neha Soni  Keyboard  Accessories  Logitech  57140         4
# 297  ORD1298    Mohit Gupta   Printer       Office     Canon  28653         2
# 301  ORD1012    Deepak Jain   Printer       Office     Canon  29246         2
#
#           City  State  Order_Date Delivery_Status  Rating  \
# 2       Jaipur     RJ  13-03-2025       Delivered     5.0
# 8         Pune     MH  15-01-2025       Delivered     3.0
# 11      Nagpur     MH  07-05-2025       Delivered     5.0
# 16   Hyderabad     TS  20-03-2025       Delivered     3.0
# 17      Indore     MP  02-02-2025       Delivered     5.0
# ..         ...    ...         ...             ...     ...
# 292     Bhopal     MP  17-04-2025       Delivered     3.0
# 294     Nagpur     MH  30-01-2025       Delivered     1.0
# 296      Delhi  Delhi  07-06-2025       Delivered     1.0
# 297     Bhopal     MP  30-06-2025       Delivered     3.0
# 301     Nagpur     MH  07-05-2025       Delivered     5.0
#
#                                 Review Payment_Mode  Total_Amount
# 2      Average Quality (Late Delivery)   Debit Card        117572
# 8    Excellent Product (Fast Delivery)  Credit Card        147000
# 11   Excellent Product (Fast Delivery)          UPI         58492
# 16   Excellent Product (Fast Delivery)         Cash          3052
# 17      Nice Product (Value for Money)  Net Banking         64199
# ..                                 ...          ...           ...
# 292           Good Product (Satisfied)         Cash         63777
# 294            Bad Packaging (Delayed)          UPI         27912
# 296     Nice Product (Value for Money)  Net Banking        228560
# 297                  Amazing (5 Stars)          UPI         57306
# 301  Excellent Product (Fast Delivery)          UPI         58492
#
# [88 rows x 15 columns]

# %% [markdown]
# Q12. Show products with Price > 50000.

# %%
# Write your code here
df[df['Price'] > 50000]
# Out:
#     Order_ID         Customer      Product     Category     Brand  Price  \
# 5    ORD1006      Vivek Joshi  Smart Watch  Electronics     Apple  76174
# 6    ORD1007      Priya Singh        Mouse  Accessories  Logitech  50323
# 8    ORD1009      Simran Kaur      Printer       Office     Canon  73500
# 12   ORD1013      Rohit Patel     Keyboard  Accessories  Logitech  78672
# 17   ORD1018      Deepak Jain       Mobile  Electronics   Samsung  64199
# ..       ...              ...          ...          ...       ...    ...
# 293  ORD1294      Arjun Mehta      Monitor  Electronics      Dell  60181
# 295  ORD1296       Sneha Jain        Mouse  Accessories  Logitech  72839
# 296  ORD1297        Neha Soni     Keyboard  Accessories  Logitech  57140
# 299  ORD1300    Pooja Yadav    Smart Watch  Electronics     Apple  51951
# 302  ORD1013      Rohit Patel     Keyboard  Accessories  Logitech  78672
#
#      Quantity    City  State  Order_Date Delivery_Status  Rating  \
# 5           2  Nagpur     MH  12-01-2025       Cancelled     1.0
# 6           3  Indore     MP  12-06-2025         Pending     4.0
# 8           2    Pune     MH  15-01-2025       Delivered     3.0
# 12          1  Jaipur     RJ  08-04-2025       Cancelled     4.0
# 17          1  Indore     MP  02-02-2025       Delivered     5.0
# ..        ...     ...    ...         ...             ...     ...
# 293         2  Nagpur     MH  04-05-2025         Pending     5.0
# 295         2   Delhi  Delhi  24-05-2025         Pending     3.0
# 296         4   Delhi  Delhi  07-06-2025       Delivered     1.0
# 299         5  Jaipur     RJ  31-03-2025         Pending     1.0
# 302         1  Jaipur     RJ  08-04-2025       Cancelled     4.0
#
#                                 Review Payment_Mode  Total_Amount
# 5              Very Nice (Recommended)  Credit Card        152348
# 6      Average Quality (Late Delivery)  Credit Card        150969
# 8    Excellent Product (Fast Delivery)  Credit Card        147000
# 12      Nice Product (Value for Money)  Net Banking         78672
# 17      Nice Product (Value for Money)  Net Banking         64199
# ..                                 ...          ...           ...
# 293     Nice Product (Value for Money)          UPI        120362
# 295     Nice Product (Value for Money)         Cash        145678
# 296     Nice Product (Value for Money)  Net Banking        228560
# 299     Nice Product (Value for Money)  Net Banking        259755
# 302     Nice Product (Value for Money)  Net Banking         78672
#
# [120 rows x 15 columns]

# %% [markdown]
# ## Q13. Show customers from Bhopal.

# %%
# Write your code here
df[df['City'] == 'Bhopal'][['Customer', 'City']]
# Out:
#            Customer    City
# 1       Deepak Jain  Bhopal
# 13       Nikita Rao  Bhopal
# 43       Karan Shah  Bhopal
# 61      Mohit Gupta  Bhopal
# 63      Simran Kaur  Bhopal
# 70      Riya Tiwari  Bhopal
# 92     Nikita Rao    Bhopal
# 98       Sneha Jain  Bhopal
# 111     Simran Kaur  Bhopal
# 114    Rahul Sharma  Bhopal
# 120      Karan Shah  Bhopal
# 140   Sakshi Sharma  Bhopal
# 146       Neha Soni  Bhopal
# 147     Pooja Yadav  Bhopal
# 155      Nikita Rao  Bhopal
# 157     Deepak Jain  Bhopal
# 165   Harsh Agrawal  Bhopal
# 171     Simran Kaur  Bhopal
# 175     Vivek Joshi  Bhopal
# 176   Sakshi Sharma  Bhopal
# 178     Arjun Mehta  Bhopal
# 215     Vivek Joshi  Bhopal
# 219   Sakshi Sharma  Bhopal
# 228      Karan Shah  Bhopal
# 229     Vivek Joshi  Bhopal
# 234     Pooja Yadav  Bhopal
# 242     Arjun Mehta  Bhopal
# 251   Harsh Agrawal  Bhopal
# 255      Nikita Rao  Bhopal
# 273     Riya Tiwari  Bhopal
# 292     Rohit Patel  Bhopal
# 297     Mohit Gupta  Bhopal

# %% [markdown]
# ## Q14. Show Rating >= 4.

# %%
# Write your code here
df[df['Rating'] >= 4]
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 2    ORD1003  Harsh Agrawal        Mouse  Accessories  Logitech  29393
# 4    ORD1005    Arjun Mehta  Smart Watch  Electronics     Apple   6195
# 6    ORD1007    Priya Singh        Mouse  Accessories  Logitech  50323
# 10   ORD1011    Simran Kaur     Keyboard  Accessories  Logitech  18801
# 11   ORD1012    Deepak Jain      Printer       Office     Canon  29246
# ..       ...            ...          ...          ...       ...    ...
# 293  ORD1294    Arjun Mehta      Monitor  Electronics      Dell  60181
# 298  ORD1299  Harsh Agrawal     Keyboard  Accessories  Logitech  43227
# 300  ORD1011    Simran Kaur     Keyboard  Accessories  Logitech  18801
# 301  ORD1012    Deepak Jain      Printer       Office     Canon  29246
# 302  ORD1013    Rohit Patel     Keyboard  Accessories  Logitech  78672
#
#      Quantity    City State  Order_Date Delivery_Status  Rating  \
# 2           4  Jaipur    RJ  13-03-2025       Delivered     5.0
# 4           4    Pune    MH  01-02-2025         Pending     5.0
# 6           3  Indore    MP  12-06-2025         Pending     4.0
# 10          2    Pune    MH  18-05-2025         Pending     5.0
# 11          2  Nagpur    MH  07-05-2025       Delivered     5.0
# ..        ...     ...   ...         ...             ...     ...
# 293         2  Nagpur    MH  04-05-2025         Pending     5.0
# 298         2  Nagpur    MH  30-01-2025         Pending     4.0
# 300         2    Pune    MH  18-05-2025         Pending     5.0
# 301         2  Nagpur    MH  07-05-2025       Delivered     5.0
# 302         1  Jaipur    RJ  08-04-2025       Cancelled     4.0
#
#                                 Review Payment_Mode  Total_Amount
# 2      Average Quality (Late Delivery)   Debit Card        117572
# 4             Good Product (Satisfied)  Net Banking         24780
# 6      Average Quality (Late Delivery)  Credit Card        150969
# 10                   Amazing (5 Stars)   Debit Card         37602
# 11   Excellent Product (Fast Delivery)          UPI         58492
# ..                                 ...          ...           ...
# 293     Nice Product (Value for Money)          UPI        120362
# 298     Nice Product (Value for Money)  Net Banking         86454
# 300                  Amazing (5 Stars)   Debit Card         37602
# 301  Excellent Product (Fast Delivery)          UPI         58492
# 302     Nice Product (Value for Money)  Net Banking         78672
#
# [132 rows x 15 columns]

# %% [markdown]
# ## Q15. Show Electronics category.

# %%
# Write your code here
df[df['Category'] == 'Electronics']
# Out:
#     Order_ID          Customer      Product     Category  Brand  Price  \
# 0    ORD1001    Anjali Gupta         Laptop  Electronics     HP  32598
# 3    ORD1004       Pooja Yadav      Monitor  Electronics   Dell  28721
# 4    ORD1005       Arjun Mehta  Smart Watch  Electronics  Apple   6195
# 5    ORD1006       Vivek Joshi  Smart Watch  Electronics  Apple  76174
# 9    ORD1010         Neha Soni      Monitor  Electronics   Dell  28153
# ..       ...               ...          ...          ...    ...    ...
# 284  ORD1285       Vivek Joshi       Tablet  Electronics  Apple  63284
# 289  ORD1290        Aman Verma       Tablet  Electronics  Apple  14835
# 292  ORD1293       Rohit Patel       Tablet  Electronics  Apple  63777
# 293  ORD1294       Arjun Mehta      Monitor  Electronics   Dell  60181
# 299  ORD1300     Pooja Yadav    Smart Watch  Electronics  Apple  51951
#
#      Quantity    City  State  Order_Date Delivery_Status  Rating  \
# 0           2    Pune     MH  27-01-2025       Cancelled     2.0
# 3           3   Delhi  Delhi  24-01-2025         Pending     1.0
# 4           4    Pune     MH  01-02-2025         Pending     5.0
# 5           2  Nagpur     MH  12-01-2025       Cancelled     1.0
# 9           5  Indore     MP  24-02-2025       Cancelled     3.0
# ..        ...     ...    ...         ...             ...     ...
# 284         3  Mumbai     MH  12-04-2025         Pending     2.0
# 289         2  Indore     MP  12-02-2025       Cancelled     3.0
# 292         1  Bhopal     MP  17-04-2025       Delivered     3.0
# 293         2  Nagpur     MH  04-05-2025         Pending     5.0
# 299         5  Jaipur     RJ  31-03-2025         Pending     1.0
#
#                              Review Payment_Mode  Total_Amount
# 0           Poor Quality (Returned)          UPI         65196
# 3          Good Product (Satisfied)  Credit Card         86163
# 4          Good Product (Satisfied)  Net Banking         24780
# 5           Very Nice (Recommended)  Credit Card        152348
# 9    Nice Product (Value for Money)   Debit Card        140765
# ..                              ...          ...           ...
# 284   Worth Buying (Happy Customer)   Debit Card        189852
# 289               Amazing (5 Stars)          UPI         29670
# 292        Good Product (Satisfied)         Cash         63777
# 293  Nice Product (Value for Money)          UPI        120362
# 299  Nice Product (Value for Money)  Net Banking        259755
#
# [145 rows x 15 columns]

# %% [markdown]
# ## Q16. Sort by Price (Ascending).

# %%
# Write your code here
df.sort_values(by='Price', ascending=True)
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 101  ORD1102    Pooja Yadav    Headphone  Accessories      Sony    836
# 14   ORD1015    Mohit Gupta     Keyboard  Accessories  Logitech    925
# 20   ORD1021     Karan Shah  Smart Watch  Electronics     Apple   1442
# 146  ORD1147      Neha Soni  Smart Watch  Electronics     Apple   1507
# 279  ORD1280  Sakshi Sharma       Tablet  Electronics     Apple   2117
# ..       ...            ...          ...          ...       ...    ...
# 302  ORD1013    Rohit Patel     Keyboard  Accessories  Logitech  78672
# 160  ORD1161      Neha Soni      Printer       Office     Canon  78866
# 161  ORD1162    Neha Soni        Monitor  Electronics      Dell  79497
# 213  ORD1214    Riya Tiwari      Speaker  Accessories      Boat  79963
# 114  ORD1115   Rahul Sharma  Smart Watch  Electronics     Apple  79982
#
#      Quantity       City  State  Order_Date Delivery_Status  Rating  \
# 101         3       Pune     MH  31-05-2025       Cancelled     3.0
# 14          3  Hyderabad     TS  15-02-2025       Cancelled     5.0
# 20          1     Mumbai     MH  28-02-2025       Delivered     1.0
# 146         2     Bhopal     MP  24-02-2025       Delivered     3.0
# 279         3     Jaipur     RJ  10-04-2025       Delivered     4.0
# ..        ...        ...    ...         ...             ...     ...
# 302         1     Jaipur     RJ  08-04-2025       Cancelled     4.0
# 160         1     Nagpur     MH  17-01-2025         Pending     3.0
# 161         2       Pune     MH  21-01-2025       Cancelled     3.0
# 213         5      Delhi  Delhi  25-03-2025       Cancelled     2.0
# 114         4     Bhopal     MP  28-02-2025       Cancelled     3.0
#
#                                 Review Payment_Mode  Total_Amount
# 101     Nice Product (Value for Money)         Cash          2508
# 14            Good Product (Satisfied)  Credit Card          2775
# 20   Excellent Product (Fast Delivery)  Credit Card          1442
# 146      Worth Buying (Happy Customer)  Credit Card          3014
# 279            Poor Quality (Returned)         Cash          6351
# ..                                 ...          ...           ...
# 302     Nice Product (Value for Money)  Net Banking         78672
# 160           Good Product (Satisfied)  Net Banking         78866
# 161    Average Quality (Late Delivery)  Credit Card        158994
# 213            Bad Packaging (Delayed)         Cash        399815
# 114            Bad Packaging (Delayed)         Cash        319928
#
# [303 rows x 15 columns]

# %% [markdown]
# ## Q17. Sort by Total_Amount (Descending).

# %%
# Write your code here\
df.sort_values(by='Total_Amount', ascending=False)
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 213  ORD1214    Riya Tiwari      Speaker  Accessories      Boat  79963
# 282  ORD1283     Nikita Rao        Mouse  Accessories  Logitech  78331
# 62   ORD1063  Harsh Agrawal       Laptop  Electronics        HP  78080
# 216  ORD1217  Sakshi Sharma      Speaker  Accessories      Boat  76321
# 249  ORD1250     Karan Shah  Smart Watch  Electronics     Apple  76190
# ..       ...            ...          ...          ...       ...    ...
# 16   ORD1017  Sakshi Sharma       Tablet  Electronics     Apple   3052
# 146  ORD1147      Neha Soni  Smart Watch  Electronics     Apple   1507
# 14   ORD1015    Mohit Gupta     Keyboard  Accessories  Logitech    925
# 101  ORD1102    Pooja Yadav    Headphone  Accessories      Sony    836
# 20   ORD1021     Karan Shah  Smart Watch  Electronics     Apple   1442
#
#      Quantity       City  State  Order_Date Delivery_Status  Rating  \
# 213         5      Delhi  Delhi  25-03-2025       Cancelled     2.0
# 282         5  Hyderabad     TS  28-04-2025       Delivered     2.0
# 62          5     Jaipur     RJ  22-01-2025       Cancelled     1.0
# 216         5       Pune     MH  14-01-2025       Cancelled     2.0
# 249         5     Nagpur     MH  02-03-2025         Pending     3.0
# ..        ...        ...    ...         ...             ...     ...
# 16          1  Hyderabad     TS  20-03-2025       Delivered     3.0
# 146         2     Bhopal     MP  24-02-2025       Delivered     3.0
# 14          3  Hyderabad     TS  15-02-2025       Cancelled     5.0
# 101         3       Pune     MH  31-05-2025       Cancelled     3.0
# 20          1     Mumbai     MH  28-02-2025       Delivered     1.0
#
#                                 Review Payment_Mode  Total_Amount
# 213            Bad Packaging (Delayed)         Cash        399815
# 282    Average Quality (Late Delivery)  Credit Card        391655
# 62                Excellent (Must Buy)         Cash        390400
# 216     Nice Product (Value for Money)         Cash        381605
# 249    Average Quality (Late Delivery)  Net Banking        380950
# ..                                 ...          ...           ...
# 16   Excellent Product (Fast Delivery)         Cash          3052
# 146      Worth Buying (Happy Customer)  Credit Card          3014
# 14            Good Product (Satisfied)  Credit Card          2775
# 101     Nice Product (Value for Money)         Cash          2508
# 20   Excellent Product (Fast Delivery)  Credit Card          1442
#
# [303 rows x 15 columns]

# %% [markdown]
# ## Q18. Sort by City then Price.

# %%
# Write your code here
df.sort_values(by=['City', 'Price'])
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 146  ORD1147      Neha Soni  Smart Watch  Electronics     Apple   1507
# 1    ORD1002    Deepak Jain      Printer       Office     Canon   4405
# 242  ORD1243    Arjun Mehta       Mobile  Electronics   Samsung   9546
# 255  ORD1256     Nikita Rao      Printer       Office     Canon  10039
# 273  ORD1274    Riya Tiwari       Tablet  Electronics     Apple  13303
# ..       ...            ...          ...          ...       ...    ...
# 216  ORD1217  Sakshi Sharma      Speaker  Accessories      Boat  76321
# 76   ORD1077      Neha Soni        Mouse  Accessories  Logitech  76725
# 145  ORD1146    Mohit Gupta       Mobile  Electronics   Samsung  78243
# 214  ORD1215      Neha Soni  Smart Watch  Electronics     Apple  78320
# 161  ORD1162    Neha Soni        Monitor  Electronics      Dell  79497
#
#      Quantity    City State  Order_Date Delivery_Status  Rating  \
# 146         2  Bhopal    MP  24-02-2025       Delivered     3.0
# 1           1  Bhopal    MP  01-03-2025       Cancelled     2.0
# 242         4  Bhopal    MP  15-03-2025         Pending     1.0
# 255         2  Bhopal    MP  21-06-2025       Cancelled     5.0
# 273         4  Bhopal    MP  20-01-2025         Pending     2.0
# ..        ...     ...   ...         ...             ...     ...
# 216         5    Pune    MH  14-01-2025       Cancelled     2.0
# 76          3    Pune    MH  22-05-2025       Cancelled     4.0
# 145         4    Pune    MH  20-06-2025         Pending     5.0
# 214         3    Pune    MH  11-05-2025       Cancelled     5.0
# 161         2    Pune    MH  21-01-2025       Cancelled     3.0
#
#                                 Review Payment_Mode  Total_Amount
# 146      Worth Buying (Happy Customer)  Credit Card          3014
# 1                    Amazing (5 Stars)          UPI          4405
# 242    Average Quality (Late Delivery)         Cash         38184
# 255            Very Nice (Recommended)   Debit Card         20078
# 273                  Amazing (5 Stars)  Net Banking         53212
# ..                                 ...          ...           ...
# 216     Nice Product (Value for Money)         Cash        381605
# 76             Bad Packaging (Delayed)   Debit Card        230175
# 145  Excellent Product (Fast Delivery)         Cash        312972
# 214     Nice Product (Value for Money)  Net Banking        234960
# 161    Average Quality (Late Delivery)  Credit Card        158994
#
# [303 rows x 15 columns]

# %% [markdown]
# ## Q19. Convert Customer to uppercase.

# %%
# Write your code here
df['Customer'] = df['Customer'].str.upper()

# %% [markdown]
# ## Q20. Convert Product to lowercase.

# %%
# Write your code here
df['Product'] = df['Product'].str.lower()

# %% [markdown]
# ## Q21. Remove everything after '(' from Review.

# %%
# Write your code here
df['Review'] = df['Review'].str.split('(').str[0].str.strip()

# %% [markdown]
# ## Q22. Find customers whose names start with 'A'.

# %%
# Write your code here
df[df['Customer'].str.startswith('A')]
# Out:
#     Order_ID      Customer      Product     Category     Brand  Price  \
# 4    ORD1005   ARJUN MEHTA  smart watch  Electronics     Apple   6195
# 7    ORD1008   ARJUN MEHTA        mouse  Accessories  Logitech   9858
# 22   ORD1023   AKASH DUBEY        mouse  Accessories  Logitech  53854
# 29   ORD1030    AMAN VERMA  smart watch  Electronics     Apple  66409
# 31   ORD1032    AMAN VERMA  smart watch  Electronics     Apple  55448
# 39   ORD1040    AMAN VERMA       tablet  Electronics     Apple  56833
# 40   ORD1041  ADITI MISHRA        mouse  Accessories  Logitech  46857
# 45   ORD1046  ANJALI GUPTA  smart watch  Electronics     Apple  45809
# 52   ORD1053    AMAN VERMA        mouse  Accessories  Logitech  10045
# 53   ORD1054   AKASH DUBEY      printer       Office     Canon  19842
# 59   ORD1060  ADITI MISHRA      printer       Office     Canon  77056
# 65   ORD1066   ARJUN MEHTA        mouse  Accessories  Logitech   5776
# 75   ORD1076   AKASH DUBEY    headphone  Accessories      Sony  62902
# 81   ORD1082  ANJALI GUPTA       laptop  Electronics        HP  62024
# 82   ORD1083   AKASH DUBEY       mobile  Electronics   Samsung  53021
# 97   ORD1098  ADITI MISHRA      monitor  Electronics      Dell  38252
# 103  ORD1104  ADITI MISHRA        mouse  Accessories  Logitech  31113
# 105  ORD1106  ANJALI GUPTA    headphone  Accessories      Sony   2511
# 107  ORD1108    AMAN VERMA  smart watch  Electronics     Apple  31271
# 116  ORD1117   ARJUN MEHTA     keyboard  Accessories  Logitech  39180
# 117  ORD1118   ARJUN MEHTA    headphone  Accessories      Sony  22067
# 122  ORD1123  ANJALI GUPTA        mouse  Accessories  Logitech  51440
# 124  ORD1125  ADITI MISHRA      speaker  Accessories      Boat  31447
# 125  ORD1126    AMAN VERMA      printer       Office     Canon  25378
# 130  ORD1131   AKASH DUBEY      speaker  Accessories      Boat  67771
# 131  ORD1132    AMAN VERMA    headphone  Accessories      Sony  60536
# 132  ORD1133   AKASH DUBEY      speaker  Accessories      Boat  11089
# 139  ORD1140  ANJALI GUPTA       tablet  Electronics     Apple  15558
# 141  ORD1142   ARJUN MEHTA       laptop  Electronics        HP  19276
# 153  ORD1154  ADITI MISHRA     keyboard  Accessories  Logitech  10376
# 156  ORD1157    AMAN VERMA       tablet  Electronics     Apple  10557
# 173  ORD1174    AMAN VERMA      monitor  Electronics      Dell  18691
# 178  ORD1179   ARJUN MEHTA       mobile  Electronics   Samsung  51677
# 180  ORD1181    AMAN VERMA       tablet  Electronics     Apple  23449
# 191  ORD1192  ANJALI GUPTA      monitor  Electronics      Dell  58993
# 192  ORD1193  ANJALI GUPTA     keyboard  Accessories  Logitech  59750
# 194  ORD1195  ADITI MISHRA     keyboard  Accessories  Logitech  65252
# 199  ORD1200  ADITI MISHRA    headphone  Accessories      Sony  16906
# 221  ORD1222   AKASH DUBEY        mouse  Accessories  Logitech  37069
# 222  ORD1223   AKASH DUBEY       tablet  Electronics     Apple  46218
# 225  ORD1226  ANJALI GUPTA  smart watch  Electronics     Apple  32279
# 226  ORD1227  ANJALI GUPTA      printer       Office     Canon  62418
# 227  ORD1228   AKASH DUBEY      speaker  Accessories      Boat  38149
# 237  ORD1238   AKASH DUBEY    headphone  Accessories      Sony  32935
# 240  ORD1241    AMAN VERMA      speaker  Accessories      Boat  67772
# 242  ORD1243   ARJUN MEHTA       mobile  Electronics   Samsung   9546
# 244  ORD1245   ARJUN MEHTA       mobile  Electronics   Samsung  70919
# 246  ORD1247   ARJUN MEHTA     keyboard  Accessories  Logitech  25204
# 248  ORD1249    AMAN VERMA      printer       Office     Canon  31215
# 254  ORD1255  ADITI MISHRA       tablet  Electronics     Apple  59454
# 256  ORD1257  ADITI MISHRA       tablet  Electronics     Apple   2509
# 258  ORD1259   ARJUN MEHTA      monitor  Electronics      Dell  47639
# 259  ORD1260  ADITI MISHRA       tablet  Electronics     Apple  54754
# 264  ORD1265   ARJUN MEHTA       laptop  Electronics        HP  64444
# 266  ORD1267  ANJALI GUPTA       mobile  Electronics   Samsung  32084
# 270  ORD1271  ADITI MISHRA  smart watch  Electronics     Apple  36032
# 271  ORD1272    AMAN VERMA     keyboard  Accessories  Logitech   2552
# 289  ORD1290    AMAN VERMA       tablet  Electronics     Apple  14835
# 293  ORD1294   ARJUN MEHTA      monitor  Electronics      Dell  60181
#
#      Quantity       City  State  Order_Date Delivery_Status  Rating  \
# 4           4       Pune     MH  01-02-2025         Pending     5.0
# 7           5       Pune     MH  17-05-2025       Cancelled     2.0
# 22          2  Hyderabad     TS  25-01-2025       Cancelled     1.0
# 29          5  Hyderabad     TS  15-01-2025       Cancelled     2.0
# 31          5     Indore     MP  14-05-2025         Pending     5.0
# 39          2      Delhi  Delhi  20-03-2025         Pending     1.0
# 40          5     Indore     MP  08-06-2025       Cancelled     4.0
# 45          3     Jaipur     RJ  05-06-2025       Cancelled     4.0
# 52          4  Hyderabad     TS  11-06-2025       Cancelled     4.0
# 53          1     Mumbai     MH  19-04-2025       Delivered     1.0
# 59          1     Jaipur     RJ  08-04-2025         Pending     5.0
# 65          1     Indore     MP  21-02-2025       Delivered     2.0
# 75          4     Mumbai     MH  05-01-2025       Delivered     4.0
# 81          4       Pune     MH  29-03-2025       Delivered     4.0
# 82          4     Indore     MP  28-05-2025       Cancelled     1.0
# 97          4      Delhi  Delhi  01-02-2025       Delivered     4.0
# 103         4     Jaipur     RJ  23-03-2025       Cancelled     1.0
# 105         2  Hyderabad     TS  17-06-2025       Delivered     4.0
# 107         3     Indore     MP  24-01-2025         Pending     2.0
# 116         3     Indore     MP  14-02-2025       Delivered     4.0
# 117         3       Pune     MH  17-03-2025       Cancelled     4.0
# 122         4      Delhi  Delhi  21-06-2025       Cancelled     3.0
# 124         3  Hyderabad     TS  25-06-2025         Pending     1.0
# 125         1       Pune     MH  24-01-2025       Cancelled     4.0
# 130         5     Nagpur     MH  26-04-2025       Cancelled     1.0
# 131         1       Pune     MH  03-05-2025         Pending     1.0
# 132         3     Indore     MP  07-02-2025       Delivered     5.0
# 139         3     Nagpur     MH  27-02-2025         Pending     5.0
# 141         5      Delhi  Delhi  18-01-2025       Delivered     4.0
# 153         2      Delhi  Delhi  29-04-2025       Cancelled     4.0
# 156         1       Pune     MH  02-06-2025       Cancelled     5.0
# 173         4  Hyderabad     TS  07-06-2025       Delivered     4.0
# 178         4     Bhopal     MP  12-06-2025         Pending     1.0
# 180         4     Nagpur     MH  11-06-2025       Delivered     4.0
# 191         2       Pune     MH  15-03-2025       Cancelled     5.0
# 192         2     Indore     MP  23-01-2025       Cancelled     4.0
# 194         1     Mumbai     MH  22-05-2025       Cancelled     3.0
# 199         3       Pune     MH  07-06-2025       Cancelled     0.0
# 221         5     Mumbai     MH  27-02-2025         Pending     3.0
# 222         5  Hyderabad     TS  15-03-2025       Delivered     3.0
# 225         1     Mumbai     MH  27-02-2025       Cancelled     5.0
# 226         1     Nagpur     MH  02-01-2025       Cancelled     2.0
# 227         3     Mumbai     MH  15-06-2025       Delivered     3.0
# 237         5     Mumbai     MH  15-05-2025         Pending     1.0
# 240         4      Delhi  Delhi  25-05-2025       Delivered     4.0
# 242         4     Bhopal     MP  15-03-2025         Pending     1.0
# 244         4      Delhi  Delhi  02-02-2025       Cancelled     5.0
# 246         1       Pune     MH  19-06-2025         Pending     1.0
# 248         5  Hyderabad     TS  15-01-2025       Delivered     2.0
# 254         3     Indore     MP  18-05-2025       Cancelled     1.0
# 256         2       Pune     MH  31-01-2025       Cancelled     2.0
# 258         5       Pune     MH  30-04-2025       Delivered     4.0
# 259         1     Nagpur     MH  26-02-2025       Cancelled     5.0
# 264         1  Hyderabad     TS  17-05-2025       Cancelled     1.0
# 266         2      Delhi  Delhi  15-05-2025         Pending     5.0
# 270         1  Hyderabad     TS  25-06-2025         Pending     1.0
# 271         2     Nagpur     MH  06-02-2025       Cancelled     5.0
# 289         2     Indore     MP  12-02-2025       Cancelled     3.0
# 293         2     Nagpur     MH  04-05-2025         Pending     5.0
#
#                 Review Payment_Mode  Total_Amount
# 4         Good Product  Net Banking         24780
# 7            Very Nice         Cash         49290
# 22           Excellent  Credit Card        107708
# 29        Good Product         Cash        332045
# 31        Worth Buying         Cash        277240
# 39   Excellent Product  Credit Card        113666
# 40     Average Quality         Cash        234285
# 45        Good Product   Debit Card        137427
# 52           Very Nice   Debit Card         40180
# 53     Average Quality  Net Banking         19842
# 59   Excellent Product  Credit Card         77056
# 65             Amazing         Cash          5776
# 75        Worth Buying         Cash        251608
# 81   Excellent Product  Credit Card        248096
# 82   Excellent Product         Cash        212084
# 97             Amazing         Cash        153008
# 103       Nice Product   Debit Card        124452
# 105       Good Product   Debit Card          5022
# 107       Good Product          UPI         93813
# 116    Average Quality  Net Banking        117540
# 117      Bad Packaging          UPI         66201
# 122       Poor Quality   Debit Card        205760
# 124       Poor Quality  Credit Card         94341
# 125          Very Nice  Net Banking         25378
# 130          Very Nice  Net Banking        338855
# 131          Excellent          UPI         60536
# 132    Average Quality  Credit Card         33267
# 139       Poor Quality  Net Banking         46674
# 141  Excellent Product          UPI         96380
# 153            Amazing   Debit Card         20752
# 156          Excellent   Debit Card         10557
# 173       Good Product          UPI         74764
# 178      Bad Packaging  Credit Card        206708
# 180    Average Quality          UPI         93796
# 191       Nice Product         Cash        117986
# 192      Bad Packaging  Credit Card        119500
# 194      Bad Packaging   Debit Card         65252
# 199       Good Product  Net Banking         50718
# 221       Worth Buying         Cash        185345
# 222            Amazing  Net Banking        231090
# 225          Very Nice          UPI         32279
# 226    Average Quality   Debit Card         62418
# 227       Good Product  Net Banking        114447
# 237       Poor Quality  Credit Card        164675
# 240       Poor Quality   Debit Card        271088
# 242    Average Quality         Cash         38184
# 244          Very Nice          UPI        283676
# 246            Amazing          UPI         25204
# 248       Poor Quality  Credit Card        156075
# 254          Very Nice          UPI        178362
# 256       Nice Product         Cash          5018
# 258       Nice Product  Credit Card        238195
# 259    Average Quality          UPI         54754
# 264          Excellent          UPI         64444
# 266      Bad Packaging  Credit Card         64168
# 270       Poor Quality  Net Banking         36032
# 271          Excellent          UPI          5104
# 289            Amazing          UPI         29670
# 293       Nice Product          UPI        120362

# %% [markdown]
# ## Q23. Find reviews containing 'Good'.

# %%
# Write your code here
df[df['Review'].str.contains('Good', na=False)]
# Out:
#     Order_ID           Customer      Product     Category     Brand  Price  \
# 3    ORD1004        POOJA YADAV      monitor  Electronics      Dell  28721
# 4    ORD1005        ARJUN MEHTA  smart watch  Electronics     Apple   6195
# 13   ORD1014         NIKITA RAO    headphone  Accessories      Sony  15514
# 14   ORD1015        MOHIT GUPTA     keyboard  Accessories  Logitech    925
# 29   ORD1030         AMAN VERMA  smart watch  Electronics     Apple  66409
# 32   ORD1033        POOJA YADAV        mouse  Accessories  Logitech  52376
# 45   ORD1046       ANJALI GUPTA  smart watch  Electronics     Apple  45809
# 56   ORD1057         NIKITA RAO        mouse  Accessories  Logitech  68827
# 77   ORD1078      HARSH AGRAWAL       tablet  Electronics     Apple  59973
# 89   ORD1090        PRIYA SINGH       laptop  Electronics        HP  40819
# 104  ORD1105          NEHA SONI     keyboard  Accessories  Logitech   5352
# 105  ORD1106       ANJALI GUPTA    headphone  Accessories      Sony   2511
# 107  ORD1108         AMAN VERMA  smart watch  Electronics     Apple  31271
# 120  ORD1121         KARAN SHAH      speaker  Accessories      Boat  74084
# 129  ORD1130        POOJA YADAV       laptop  Electronics        HP  35282
# 143  ORD1144        DEEPAK JAIN  smart watch  Electronics     Apple   7395
# 144  ORD1145        SIMRAN KAUR      printer       Office     Canon  58439
# 160  ORD1161          NEHA SONI      printer       Office     Canon  78866
# 164  ORD1165        POOJA YADAV      speaker  Accessories      Boat  30193
# 170  ORD1171        VIVEK JOSHI       mobile  Electronics   Samsung  36255
# 173  ORD1174         AMAN VERMA      monitor  Electronics      Dell  18691
# 175  ORD1176        VIVEK JOSHI       mobile  Electronics   Samsung  31752
# 177  ORD1178      SAKSHI SHARMA       tablet  Electronics     Apple  75298
# 198  ORD1199        VIVEK JOSHI     keyboard  Accessories  Logitech  42791
# 199  ORD1200       ADITI MISHRA    headphone  Accessories      Sony  16906
# 202  ORD1203      HARSH AGRAWAL      monitor  Electronics      Dell  63800
# 217  ORD1218        RIYA TIWARI  smart watch  Electronics     Apple  19869
# 223  ORD1224          NEHA SONI      printer       Office     Canon  19698
# 227  ORD1228        AKASH DUBEY      speaker  Accessories      Boat  38149
# 230  ORD1231    HARSH AGRAWAL      headphone  Accessories      Sony  18089
# 232  ORD1233      SAKSHI SHARMA      printer       Office     Canon  68038
# 234  ORD1235        POOJA YADAV      monitor  Electronics      Dell  34782
# 262  ORD1263        ROHIT PATEL    headphone  Accessories      Sony  24623
# 276  ORD1277      PRIYA SINGH        monitor  Electronics      Dell  50307
# 278  ORD1279        SIMRAN KAUR    headphone  Accessories      Sony  14038
# 281  ORD1282        ROHIT PATEL       mobile  Electronics   Samsung  57473
# 292  ORD1293        ROHIT PATEL       tablet  Electronics     Apple  63777
#
#      Quantity       City  State  Order_Date Delivery_Status  Rating  \
# 3           3      Delhi  Delhi  24-01-2025         Pending     1.0
# 4           4       Pune     MH  01-02-2025         Pending     5.0
# 13          5     Bhopal     MP  14-06-2025         Pending     3.0
# 14          3  Hyderabad     TS  15-02-2025       Cancelled     5.0
# 29          5  Hyderabad     TS  15-01-2025       Cancelled     2.0
# 32          2       Pune     MH  28-04-2025         Pending     3.0
# 45          3     Jaipur     RJ  05-06-2025       Cancelled     4.0
# 56          4       Pune     MH  12-03-2025         Pending     2.0
# 77          3     Nagpur     MH  06-03-2025       Delivered     3.0
# 89          5      Delhi  Delhi  15-03-2025         Pending     5.0
# 104         2  Hyderabad     TS  01-06-2025         Pending     5.0
# 105         2  Hyderabad     TS  17-06-2025       Delivered     4.0
# 107         3     Indore     MP  24-01-2025         Pending     2.0
# 120         3     Bhopal     MP  26-02-2025       Cancelled     5.0
# 129         1      Delhi  Delhi  18-04-2025       Cancelled     2.0
# 143         2     Indore     MP  08-06-2025       Delivered     2.0
# 144         4  Hyderabad     TS  25-02-2025       Cancelled     3.0
# 160         1     Nagpur     MH  17-01-2025         Pending     3.0
# 164         2     Mumbai     MH  20-01-2025         Pending     2.0
# 170         4      Delhi  Delhi  07-02-2025         Pending     5.0
# 173         4  Hyderabad     TS  07-06-2025       Delivered     4.0
# 175         4     Bhopal     MP  28-04-2025       Delivered     5.0
# 177         4     Mumbai     MH  20-06-2025       Cancelled     2.0
# 198         2      Delhi  Delhi  13-05-2025         Pending     3.0
# 199         3       Pune     MH  07-06-2025       Cancelled     0.0
# 202         2       Pune     MH  18-03-2025         Pending     4.0
# 217         2     Jaipur     RJ  27-05-2025       Cancelled     1.0
# 223         3     Nagpur     MH  15-03-2025       Cancelled     1.0
# 227         3     Mumbai     MH  15-06-2025       Delivered     3.0
# 230         5  Hyderabad     TS  11-03-2025       Delivered     4.0
# 232         3     Jaipur     RJ  13-04-2025       Cancelled     1.0
# 234         3     Bhopal     MP  16-01-2025       Cancelled     2.0
# 262         5  Hyderabad     TS  15-05-2025       Delivered     1.0
# 276         2      Delhi  Delhi  23-03-2025         Pending     4.0
# 278         1     Jaipur     RJ  01-04-2025       Cancelled     1.0
# 281         3      Delhi  Delhi  18-03-2025         Pending     4.0
# 292         1     Bhopal     MP  17-04-2025       Delivered     3.0
#
#            Review Payment_Mode  Total_Amount
# 3    Good Product  Credit Card         86163
# 4    Good Product  Net Banking         24780
# 13   Good Product  Credit Card         77570
# 14   Good Product  Credit Card          2775
# 29   Good Product         Cash        332045
# 32   Good Product          UPI        104752
# 45   Good Product   Debit Card        137427
# 56   Good Product  Credit Card        275308
# 77   Good Product         Cash        179919
# 89   Good Product   Debit Card        204095
# 104  Good Product   Debit Card         10704
# 105  Good Product   Debit Card          5022
# 107  Good Product          UPI         93813
# 120  Good Product   Debit Card        222252
# 129  Good Product          UPI         35282
# 143  Good Product  Credit Card         14790
# 144  Good Product  Credit Card        233756
# 160  Good Product  Net Banking         78866
# 164  Good Product  Net Banking         60386
# 170  Good Product         Cash        145020
# 173  Good Product          UPI         74764
# 175  Good Product   Debit Card        127008
# 177  Good Product  Net Banking        301192
# 198  Good Product  Credit Card         85582
# 199  Good Product  Net Banking         50718
# 202  Good Product          UPI        127600
# 217  Good Product         Cash         39738
# 223  Good Product  Credit Card         59094
# 227  Good Product  Net Banking        114447
# 230  Good Product  Credit Card         90445
# 232  Good Product         Cash        204114
# 234  Good Product   Debit Card        104346
# 262  Good Product          UPI        123115
# 276  Good Product          UPI        100614
# 278  Good Product  Net Banking         14038
# 281  Good Product  Credit Card        172419
# 292  Good Product         Cash         63777

# %% [markdown]
# ## Q24. Remove extra spaces from Customer.

# %%
# Write your code here
df['Customer'] = df['Customer'].str.strip()

# %% [markdown]
# ## Q25. Category-wise total sales.

# %%
# Write your code here
df.groupby('Category')['Total_Amount'].sum()
# Out:
# Category
# Accessories    15627647
# Electronics    17974270
# Office          3383852
# Name: Total_Amount, dtype: int64

# %% [markdown]
# ## Q26. Brand-wise average price.

# %%
# Write your code here

df.groupby('Brand')['Price'].mean()
# Out:
# Brand
# Apple       37738.984615
# Boat        46371.892857
# Canon       40052.914286
# Dell        39726.032258
# HP          39408.000000
# Logitech    39297.841270
# Samsung     49258.200000
# Sony        37431.562500
# Name: Price, dtype: float64

# %% [markdown]
# ## Q27. Category-wise maximum price.

# %%
# Write your code here
df.groupby('Category')['Price'].max()
# Out:
# Category
# Accessories    79963
# Electronics    79982
# Office         78866
# Name: Price, dtype: int64

# %% [markdown]
# ## Q28. City-wise total quantity.

# %%
# Write your code here
df.groupby('City')['Quantity'].sum()
# Out:
# City
# Bhopal       112
# Delhi        103
# Hyderabad    122
# Indore       106
# Jaipur       136
# Mumbai        84
# Nagpur       111
# Pune         121
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Q29. Payment mode-wise average rating.

# %%
# Write your code here
df.groupby('Payment_Mode')['Rating'].mean()
# Out:
# Payment_Mode
# Cash           3.133333
# Credit Card    3.046154
# Debit Card     3.526316
# Net Banking    2.745455
# UPI            2.893939
# Name: Rating, dtype: float64

# %% [markdown]
# ## Q30. Count Delivery_Status.

# %%
# Write your code here
df['Delivery_Status'].value_counts()
# Out:
# Delivery_Status
# Cancelled    108
# Pending      107
# Delivered     88
# Name: count, dtype: int64

# %% [markdown]
# ## Q31. Count Category.

# %%
# Write your code here
df['Category'].value_counts()
# Out:
# Category
# Electronics    145
# Accessories    123
# Office          35
# Name: count, dtype: int64

# %% [markdown]
# ## Q32. Count Payment_Mode.

# %%
# Write your code here
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# UPI            66
# Credit Card    65
# Cash           60
# Debit Card     57
# Net Banking    55
# Name: count, dtype: int64

# %% [markdown]
# ## Q33. Top 5 highest sales.

# %%
# Write your code here
df.nlargest(5, 'Total_Amount')
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 213  ORD1214    RIYA TIWARI      speaker  Accessories      Boat  79963
# 282  ORD1283     NIKITA RAO        mouse  Accessories  Logitech  78331
# 62   ORD1063  HARSH AGRAWAL       laptop  Electronics        HP  78080
# 216  ORD1217  SAKSHI SHARMA      speaker  Accessories      Boat  76321
# 249  ORD1250     KARAN SHAH  smart watch  Electronics     Apple  76190
#
#      Quantity       City  State  Order_Date Delivery_Status  Rating  \
# 213         5      Delhi  Delhi  25-03-2025       Cancelled     2.0
# 282         5  Hyderabad     TS  28-04-2025       Delivered     2.0
# 62          5     Jaipur     RJ  22-01-2025       Cancelled     1.0
# 216         5       Pune     MH  14-01-2025       Cancelled     2.0
# 249         5     Nagpur     MH  02-03-2025         Pending     3.0
#
#               Review Payment_Mode  Total_Amount
# 213    Bad Packaging         Cash        399815
# 282  Average Quality  Credit Card        391655
# 62         Excellent         Cash        390400
# 216     Nice Product         Cash        381605
# 249  Average Quality  Net Banking        380950

# %% [markdown]
# ## Q34. Bottom 5 sales.

# %%
# Write your code here
df.nsmallest(5, 'Total_Amount')
# Out:
#     Order_ID       Customer      Product     Category     Brand  Price  \
# 20   ORD1021     KARAN SHAH  smart watch  Electronics     Apple   1442
# 101  ORD1102    POOJA YADAV    headphone  Accessories      Sony    836
# 14   ORD1015    MOHIT GUPTA     keyboard  Accessories  Logitech    925
# 146  ORD1147      NEHA SONI  smart watch  Electronics     Apple   1507
# 16   ORD1017  SAKSHI SHARMA       tablet  Electronics     Apple   3052
#
#      Quantity       City State  Order_Date Delivery_Status  Rating  \
# 20          1     Mumbai    MH  28-02-2025       Delivered     1.0
# 101         3       Pune    MH  31-05-2025       Cancelled     3.0
# 14          3  Hyderabad    TS  15-02-2025       Cancelled     5.0
# 146         2     Bhopal    MP  24-02-2025       Delivered     3.0
# 16          1  Hyderabad    TS  20-03-2025       Delivered     3.0
#
#                 Review Payment_Mode  Total_Amount
# 20   Excellent Product  Credit Card          1442
# 101       Nice Product         Cash          2508
# 14        Good Product  Credit Card          2775
# 146       Worth Buying  Credit Card          3014
# 16   Excellent Product         Cash          3052

# %% [markdown]
# ## Q35. Find duplicate rows.

# %%
# Write your code here
df[df.duplicated()]
# Out:
#     Order_ID     Customer   Product     Category     Brand  Price  Quantity  \
# 300  ORD1011  SIMRAN KAUR  keyboard  Accessories  Logitech  18801         2
# 301  ORD1012  DEEPAK JAIN   printer       Office     Canon  29246         2
# 302  ORD1013  ROHIT PATEL  keyboard  Accessories  Logitech  78672         1
#
#        City State  Order_Date Delivery_Status  Rating             Review  \
# 300    Pune    MH  18-05-2025         Pending     5.0            Amazing
# 301  Nagpur    MH  07-05-2025       Delivered     5.0  Excellent Product
# 302  Jaipur    RJ  08-04-2025       Cancelled     4.0       Nice Product
#
#     Payment_Mode  Total_Amount
# 300   Debit Card         37602
# 301          UPI         58492
# 302  Net Banking         78672

# %% [markdown]
# ## Q36. Remove duplicate rows.

# %%
# Write your code here
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Q37. Save cleaned data as `Cleaned_TechMart.csv`.

# %%
# Write your code here
df.to_csv('Cleaned_TechMart.csv', index=False)

# %%
print("File saved successfully as Cleaned_TechMart.csv")
# Out:
# File saved successfully as Cleaned_TechMart.csv
